# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import pymysql
import tensorflow as tf
import pandas.io.sql as psql
# Out:
# /Users/daham/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# # 전처리

# %%
# race_noheader 에서 distance 가져오기 (속력을 구하기 위해)

# primary key는 date & round

# %%
race_db = pd.read_csv('/Users/daham/Downloads/tables 181110/race_noheader.csv').drop_duplicates()
first_row_race_db = np.array(race_db.columns)
tmp_race_db = np.array(race_db)

# %%
final_race_df = pd.DataFrame(np.vstack((first_row_race_db, tmp_race_db)))
final_race_df = final_race_df[[0,1,5]]
final_race_df.columns = ['date', 'round', 'distance']

# %%
final_race_df
# Out:
#             date round distance
# 0     2018-10-07    11     1300
# 1     2018-10-07    10     1700
# 2     2018-10-07     9     2000
# 3     2018-10-07     8     1700
# 4     2018-10-07     7     1000
# 5     2018-10-07     6     1000
# 6     2018-10-07     5     1300
# 7     2018-10-07     4     1200
# 8     2018-10-07     3     1000
# 9     2018-10-07     2     1000
# 10    2018-10-07     1     1300
# 11    2018-10-06    12     1200
# 12    2018-10-06    11     1700
# 13    2018-10-06    10     1700
# 14    2018-10-06     9     1300
# 15    2018-10-06     8     1200
# 16    2018-10-06     7     1300
# 17    2018-10-06     6     1000
# 18    2018-10-06     5     1000
# 19    2018-10-06     4     1300
# 20    2018-10-06     3     1000
# 21    2018-10-06     2     1000
# 22    2018-10-06     1     1000
# 23    2018-09-30    11     1300
# 24    2018-09-30    10     2300
# 25    2018-09-30     9     1200
# 26    2018-09-30     8     1800
# 27    2018-09-30     7     1300
# 28    2018-09-30     6     1700
# 29    2018-09-30     5     1700
# ...          ...   ...      ...
# 6278  2013-01-13     6     1400
# 6279  2013-01-13     5     1200
# 6280  2013-01-13     4     1200
# 6281  2013-01-13     3     1300
# 6282  2013-01-13     2     1000
# 6283  2013-01-13     1     1300
# 6284  2013-01-12    12     1400
# 6285  2013-01-12    11     1900
# 6286  2013-01-12    10     1800
# 6287  2013-01-12     9     1800
# 6288  2013-01-12     8     1300
# 6289  2013-01-12     7     1200
# 6290  2013-01-12     6     1300
# 6291  2013-01-12     5     1300
# 6292  2013-01-12     4     1200
# 6293  2013-01-12     3     1200
# 6294  2013-01-12     2     1000
# 6295  2013-01-12     1     1300
# 6296  2012-09-02     3     1000
# 6297  2012-07-01     7     1800
# 6298  2012-04-28    10     1900
# 6299  2012-01-14    10     1900
# 6300  2011-04-02     6     1400
# 6301  2011-01-23     6     1200
# 6302  2010-12-11    10     1800
# 6303  2010-09-11    11     2000
# 6304  2010-03-21     9     1900
# 6305  2009-11-28    12     1400
# 6306  2008-08-10     9     1400
# 6307  2008-04-13     5     1000
#
# [6308 rows x 3 columns]

# %%
# to_sql_race_result 에서 모두 가져오기

# primary key는 date & round 로 해서 위의 final_race_df 와 merge

# 속도를 계산

# 이전 3경기의 순위를 새로운 컬럼에 기록 

# 이전 3경기의 속도를 새로운 컬럼에 기록

# %%
to_sql_race_result_df = pd.read_csv('/Users/daham/Downloads/tables 181110/to_sql_race_result.csv').drop_duplicates()
first_row_rae_result = np.array(to_sql_race_result_df.columns)
tmp_to_sql_race_result_df = np.array(to_sql_race_result_df)

# %%
final_to_sql_race_result_df = pd.DataFrame(np.vstack((first_row_rae_result, tmp_to_sql_race_result_df)), columns = ['url', 'date', 'round', 'name', 'code', 'rank', 'lane', 'sex', 'age', 'jockey_w', 'rating', 'jockey','difference', 'weight','dandivi', 'yeondivi', 'equipment','s1fr', 'c1r', 'c2r', 'c3r', 'c4r', 'g1fr', 's1f', 'c1', 'c2', 'c3','c4','g3f', 'record'])

# %%
merged_df_with_race_info_and_race_result = final_to_sql_race_result_df.merge(final_race_df, how='left', on=['date', 'round'])
merged_df_with_race_info_and_race_result
# Out:
#                                                      url        date round  \
# 0      http://www.gumvit.com/statv40/result_detail.ht...  2018-11-03     6
# 1      http://www.gumvit.com/statv40/result_detail.ht...  2018-11-03     6
# 2      http://www.gumvit.com/statv40/result_detail.ht...  2018-11-03     6
# 3      http://www.gumvit.com/statv40/result_detail.ht...  2018-11-03     6
# 4      http://www.gumvit.com/statv40/result_detail.ht...  2018-11-03     6
# 5      http://www.gumvit.com/statv40/result_detail.ht...  2018-11-03     6
# 6      http://www.gumvit.com/statv40/result_detail.ht...  2018-11-03     6
# 7      http://www.gumvit.com/statv40/result_detail.ht...  2018-11-03     6
# 8      http://www.gumvit.com/statv40/result_detail.ht...  2018-11-03     6
# 9      http://www.gumvit.com/statv40/result_detail.ht...  2018-11-03     6
# 10     http://www.gumvit.com/statv40/result_detail.ht...  2018-11-03     6
# 11     http://www.gumvit.com/statv40/result_detail.ht...  2018-11-03     6
# 12     http://www.gumvit.com/statv40/result_detail.ht...  2018-11-03     5
# 13     http://www.gumvit.com/statv40/result_detail.ht...  2018-11-03     5
# 14     http://www.gumvit.com/statv40/result_detail.ht...  2018-11-03     5
# 15     http://www.gumvit.com/statv40/result_detail.ht...  2018-11-03     5
# 16     http://www.gumvit.com/statv40/result_detail.ht...  2018-11-03     5
# 17     http://www.gumvit.com/statv40/result_detail.ht...  2018-11-03     5
# 18     http://www.gumvit.com/statv40/result_detail.ht...  2018-11-03     5
# 19     http://www.gumvit.com/statv40/result_detail.ht...  2018-11-03     5
# 20     http://www.gumvit.com/statv40/result_detail.ht...  2018-11-03     5
# 21     http://www.gumvit.com/statv40/result_detail.ht...  2018-11-03     5
# 22     http://www.gumvit.com/statv40/result_detail.ht...  2018-11-03     4
# 23     http://www.gumvit.com/statv40/result_detail.ht...  2018-11-03     4
# 24     http://www.gumvit.com/statv40/result_detail.ht...  2018-11-03     4
# 25     http://www.gumvit.com/statv40/result_detail.ht...  2018-11-03     4
# 26     http://www.gumvit.com/statv40/result_detail.ht...  2018-11-03     4
# 27     http://www.gumvit.com/statv40/result_detail.ht...  2018-11-03     4
# 28     http://www.gumvit.com/statv40/result_detail.ht...  2018-11-03     4
# 29     http://www.gumvit.com/statv40/result_detail.ht...  2018-11-03     4
# ...                                                  ...         ...   ...
# 70514  http://www.gumvit.com/statv40/result_detail.ht...  2013-02-02    11
# 70515  http://www.gumvit.com/statv40/result_detail.ht...  2013-02-02    11
# 70516  http://www.gumvit.com/statv40/result_detail.ht...  2013-02-02    10
# 70517  http://www.gumvit.com/statv40/result_detail.ht...  2013-02-02    10
# 70518  http://www.gumvit.com/statv40/result_detail.ht...  2013-02-02    10
# 70519  http://www.gumvit.com/statv40/result_detail.ht...  2013-02-02    10
# 70520  http://www.gumvit.com/statv40/result_detail.ht...  2013-02-02    10
# 70521  http://www.gumvit.com/statv40/result_detail.ht...  2013-02-02    10
# 70522  http://www.gumvit.com/statv40/result_detail.ht...  2013-02-02    10
# 70523  http://www.gumvit.com/statv40/result_detail.ht...  2013-02-02    10
# 70524  http://www.gumvit.com/statv40/result_detail.ht...  2013-02-02    10
# 70525  http://www.gumvit.com/statv40/result_detail.ht...  2013-02-02    10
# 70526  http://www.gumvit.com/statv40/result_detail.ht...  2013-02-02    10
# 70527  http://www.gumvit.com/statv40/result_detail.ht...  2013-02-02    10
# 70528  http://www.gumvit.com/statv40/result_detail.ht...  2013-02-02    10
# 70529  http://www.gumvit.com/statv40/result_detail.ht...  2013-02-02    10
# 70530  http://www.gumvit.com/statv40/result_detail.ht...  2013-02-02     9
# 70531  http://www.gumvit.com/statv40/result_detail.ht...  2013-02-02     9
# 70532  http://www.gumvit.com/statv40/result_detail.ht...  2013-02-02     9
# 70533  http://www.gumvit.com/statv40/result_detail.ht...  2013-02-02     9
# 70534  http://www.gumvit.com/statv40/result_detail.ht...  2013-02-02     9
# 70535  http://www.gumvit.com/statv40/result_detail.ht...  2013-02-02     9
# 70536  http://www.gumvit.com/statv40/result_detail.ht...  2013-02-02     9
# 70537  http://www.gumvit.com/statv40/result_detail.ht...  2013-02-02     9
# 70538  http://www.gumvit.com/statv40/result_detail.ht...  2013-02-02     9
# 70539  http://www.gumvit.com/statv40/result_detail.ht...  2013-02-02     9
# 70540  http://www.gumvit.com/statv40/result_detail.ht...  2013-02-02     9
# 70541  http://www.gumvit.com/statv40/result_detail.ht...  2013-02-02     9
# 70542  http://www.gumvit.com/statv40/result_detail.ht...  2013-02-02     9
# 70543  http://www.gumvit.com/statv40/result_detail.ht...  2013-02-02     9
#
#          name    code rank lane sex age jockey_w   ...     c4r  g1fr  \
# 0        승리나래  036805    1    8   거   3     56.0   ...     3.2  13.8
# 1       라스트잭팟   35049    2    3   거   4       53   ...       4  14.2
# 2       승리플러스   37107    3   12   수   3     52.5   ...       5  13.8
# 3       라온제임스   38516    4    1   수   2       54   ...       1  13.7
# 4       백두의정상   37583    5    2   수   3     55.5   ...       2  13.8
# 5      백산아일랜드   34340    6    7   거   5     52.5   ...       7  14.1
# 6       스피드쇼크   40000    7    9   수   3       56   ...      10    14
# 7         개척자   33533    8    4   거   5     51.5   ...      11  14.7
# 8        더파이널   37306    9    5   암   3       55   ...       6  13.8
# 9        마이티쿨   36070   10    6   암   4       52   ...       8  14.2
# 10       모란동백   35620   11   10   암   4       53   ...       9  14.7
# 11        해들뫼   39502    취   11   수   2     55.5   ...     NaN   NaN
# 12      울트라펀치   41664    1    6   거   2       55   ...       1  13.3
# 13      피닉스울프   41654    2    1   암   2       53   ...       2  13.4
# 14      이스트쾌남   41744    3    3   수   2       55   ...       5  13.9
# 15        해나래   40115    4    4   암   2       53   ...       4  13.5
# 16      우정의향기   41753    5    5   암   2       53   ...       8    14
# 17      엠제이파워   41697    6   10   거   2       55   ...       3  13.4
# 18      베스트군함   40074    7    7   수   2       55   ...       6  13.4
# 19       아르폰스   41754    8    9   수   2       55   ...       7  13.7
# 20       청수여제   41781    9    2   암   2       53   ...      10  15.2
# 21       굿카이로   41674   10    8   수   2       55   ...       9    14
# 22     라온시리우스   37380    1    4   거   3       56   ...       2  13.6
# 23      팝스트리트   37441    2    2   수   3       54   ...       1  13.6
# 24       럭키봉화   37284    3    6   수   3       53   ...       3    14
# 25        수제비   37270    4    1   거   3     53.5   ...       4    14
# 26       맘보천하   33834    5    8   암   5       53   ...       6  14.3
# 27      금아클리프   39827    6    7   수   4     56.5   ...       7  13.9
# 28        레베카   35725    7    5   암   4       52   ...       5  13.7
# 29      터프트로피   36069    8    9   수   4       52   ...       9  14.3
# ...       ...     ...  ...  ...  ..  ..      ...   ...     ...   ...
# 70514     풀스텝   22690   11    8   수   6       50   ...      10  13.5
# 70515      본솔   22399   12    1   수   6     52.5   ...      12  14.3
# 70516    인천탱크   25897    1    9   수   4       56   ...       7  14.5
# 70517    흑룡비상   27885    2   12   수   3       54   ...       1  13.5
# 70518  브레이브마하   24063    3    8   거   5       55   ...       4  14.8
# 70519   퍼펙트특급   26890    4   13   수   4       54   ...       2  14.2
# 70520    백전필승   26308    5   10   거   4       55   ...       8  14.1
# 70521    아이리스   26120    6   14   암   4       55   ...       3  14.3
# 70522     브리그   28279    7   11   수   3       53   ...       6  13.7
# 70523   아스카호크   25828    8    5   수   4       51   ...       9  14.3
# 70524    기고만장   25378    9    1   수   5       54   ...       5  13.8
# 70525   파워이즈칸   24417   10    3   수   5       56   ...      11  14.8
# 70526    존칼리스   24279   11    4   거   5     53.5   ...      10  14.1
# 70527  라이트닝이글   26170   12    7   거   4       55   ...      12  15.5
# 70528    바다포스   25974   13    6   수   4       56   ...      13  13.9
# 70529    굿메시지   23326    취    2   거   6       50   ...     NaN   NaN
# 70530    레이징팀   29177    1   10   거   4     53.5   ...       1  13.9
# 70531  아르고프린스   31027    2    4   수   3     50.5   ...       2  13.7
# 70532    황금지존   29192    3    9   거   4       55   ...       4  13.6
# 70533   디바인스펠   29133    4   11   암   4       50   ...       5  13.5
# 70534   콜렉트더윕   31025    5   13   수   3     50.5   ...       7  13.8
# 70535   서울황태자   24821    6    1   거   5     51.5   ...       3  13.5
# 70536    서든포춘   31065    7    5   수   3     50.5   ...       6  13.4
# 70537   플라이위너   27542    8    3   암   5     50.5   ...      12  14.3
# 70538   트랜스포트   29150    9    2   수   4       54   ...       8  13.9
# 70539   요동보물섬   29140   10    6   암   4       51   ...       9  13.4
# 70540  아이엠커멘더   29147   11   12   거   4       50   ...      11    14
# 70541    리걸제시   29165   12    8   암   4       50   ...      10  13.8
# 70542  사라토가밴드   27279   13   14   암   5       50   ...      13  13.7
# 70543     수봉산   25798    실    7   수   5       52   ...      14    14
#
#                s1f           c1    c2    c3    c4   g3f record distance
# 0      Unnamed: 23  Unnamed: 24  30.9  49.8  39.2  13.6   82.6      NaN
# 1              NaN          NaN  31.7  50.2  38.7  13.6   82.7      NaN
# 2              NaN          NaN  31.2  50.1    39  13.6   82.7      NaN
# 3              NaN          NaN  30.7  49.4  39.6    14   82.7      NaN
# 4              NaN          NaN  30.7  49.5  40.2  14.5   83.4      NaN
# 5              NaN          NaN  31.7  50.4  39.3  13.7   83.4      NaN
# 6              NaN          NaN    32  51.3  38.9  13.5   83.7      NaN
# 7              NaN          NaN  32.6  51.4  38.6  13.4   83.7      NaN
# 8              NaN          NaN    31  49.8  40.3  14.3   83.7      NaN
# 9              NaN          NaN  31.9  50.8  39.5  13.9     84      NaN
# 10             NaN          NaN  32.3  50.8  40.1  14.5   84.7      NaN
# 11             NaN          NaN   NaN   NaN   NaN   NaN    NaN      NaN
# 12             NaN          NaN  13.3  29.6  36.7  13.1   60.4      NaN
# 13             NaN          NaN  13.4  29.6  37.3  13.4     61      NaN
# 14             NaN          NaN  13.9  30.6  36.7  12.8   61.3      NaN
# 15             NaN          NaN  13.5  30.3  37.4    13   61.5      NaN
# 16             NaN          NaN    14  31.3  36.9  12.6   61.9      NaN
# 17             NaN          NaN  13.4  29.9  38.1  13.9     62      NaN
# 18             NaN          NaN  13.4  30.1  38.1  13.3     62      NaN
# 19             NaN          NaN  13.7  30.8  37.5  13.4   62.1      NaN
# 20             NaN          NaN  15.2  32.1  36.5  12.3   62.6      NaN
# 21             NaN          NaN    14  31.4  37.7    13   62.8      NaN
# 22             NaN          NaN  13.6  30.9  36.5  12.6   61.2      NaN
# 23             NaN          NaN  13.6  30.9  36.8  12.9   61.5      NaN
# 24             NaN          NaN    14  31.2  37.3  13.2   62.2      NaN
# 25             NaN          NaN    14  31.2  37.7  13.3   62.6      NaN
# 26             NaN          NaN  14.3  31.5  37.5  13.2   62.8      NaN
# 27             NaN          NaN  13.9  31.5    38  13.1     63      NaN
# 28             NaN          NaN  13.7    31  38.5    14   63.3      NaN
# 29             NaN          NaN  14.3  32.6  38.1  12.9   64.1      NaN
# ...            ...          ...   ...   ...   ...   ...    ...      ...
# 70514         26.1         39.2  76.8  92.1  41.8  14.5  126.4     1900
# 70515         27.2         40.6  78.3  93.3  40.7  14.2  126.7     1900
# 70516         20.2         32.7  70.4  86.1  39.2  12.7  117.6     1800
# 70517         19.2         31.4  68.9  84.7    41  13.9  117.8     1800
# 70518         20.7         33.2    70  85.5  39.9  13.1  117.9     1800
# 70519         20.1         32.5  69.8  85.5  40.2  13.4  118.1     1800
# 70520         19.8         32.3    70  85.8  40.4  13.6  118.6     1800
# 70521         20.1         32.4  69.4  85.2  41.2  13.9  118.7     1800
# 70522         19.4         31.7  69.2  84.9  41.9  14.2  119.1     1800
# 70523         20.1         32.5    70  85.8  41.2  14.1  119.3     1800
# 70524         19.6         31.9  69.3  84.9  42.6  14.9  119.8     1800
# 70525         20.7         33.3  70.7  86.9    41  13.4    120     1800
# 70526           20         32.5  70.5  86.3    42    14  120.5     1800
# 70527         21.4         34.3  71.4  87.4  41.1  13.3  120.6     1800
# 70528         19.7           32  69.8  86.1  45.6  16.2  123.6     1800
# 70529          NaN          NaN   NaN   NaN   NaN   NaN    NaN     1800
# 70530          NaN          NaN  36.6  55.6  38.4  13.1   87.5     1400
# 70531          NaN          NaN  36.2  55.4  38.8  13.2   87.6     1400
# 70532          NaN          NaN  36.4  55.8    39  13.2   88.1     1400
# 70533          NaN          NaN  36.3  55.6  39.2  13.2   88.2     1400
# 70534          NaN          NaN  36.8    56  38.9  13.2   88.3     1400
# 70535          NaN          NaN  35.7    55    40  13.8   88.4     1400
# 70536          NaN          NaN  36.1  55.4  39.8  13.6   88.6     1400
# 70537          NaN          NaN  37.8  56.5  38.7  13.3   88.9     1400
# 70538          NaN          NaN  36.8    56  39.5  13.6   88.9     1400
# 70539          NaN          NaN  36.2  55.7  40.1  13.8   89.1     1400
# 70540          NaN          NaN  37.4  56.3  39.3  13.6   89.1     1400
# 70541          NaN          NaN  36.9  56.2    40  14.2   89.7     1400
# 70542          NaN          NaN  36.5    56  42.3  14.9   91.6     1400
# 70543          NaN          NaN  37.7  57.8  48.5  18.5   99.3     1400
#
# [70544 rows x 31 columns]

# %%
merged_df_with_race_info_and_race_result['velocity'] = merged_df_with_race_info_and_race_result['distance']/merged_df_with_race_info_and_race_result['record']
merged_df_with_race_info_and_race_result.head()
# Out:
#                                                  url        date round   name  \
# 0  http://www.gumvit.com/statv40/result_detail.ht...  2018-11-03     6   승리나래
# 1  http://www.gumvit.com/statv40/result_detail.ht...  2018-11-03     6  라스트잭팟
# 2  http://www.gumvit.com/statv40/result_detail.ht...  2018-11-03     6  승리플러스
# 3  http://www.gumvit.com/statv40/result_detail.ht...  2018-11-03     6  라온제임스
# 4  http://www.gumvit.com/statv40/result_detail.ht...  2018-11-03     6  백두의정상
#
#      code rank lane sex age jockey_w   ...     g1fr          s1f           c1  \
# 0  036805    1    8   거   3     56.0   ...     13.8  Unnamed: 23  Unnamed: 24
# 1   35049    2    3   거   4       53   ...     14.2          NaN          NaN
# 2   37107    3   12   수   3     52.5   ...     13.8          NaN          NaN
# 3   38516    4    1   수   2       54   ...     13.7          NaN          NaN
# 4   37583    5    2   수   3     55.5   ...     13.8          NaN          NaN
#
#      c2    c3    c4   g3f record distance velocity
# 0  30.9  49.8  39.2  13.6   82.6      NaN      NaN
# 1  31.7  50.2  38.7  13.6   82.7      NaN      NaN
# 2  31.2  50.1    39  13.6   82.7      NaN      NaN
# 3  30.7  49.4  39.6    14   82.7      NaN      NaN
# 4  30.7  49.5  40.2  14.5   83.4      NaN      NaN
#
# [5 rows x 32 columns]

# %%
len(merged_df_with_race_info_and_race_result)
# Out:
# 70544

# %%
horse_list = list(merged_df_with_race_info_and_race_result.name.unique())

# %%
empty_df = pd.DataFrame(columns=['date', 'name', 'rank'])

# %%
empty_list = []

# %%
for i in horse_list:
#     print(i)
#     final_to_sql_race_result_df.loc[final_to_sql_race_result_df.name=='힘찬출발', ['date','name','rank']].sort_values('date')
    tmp = merged_df_with_race_info_and_race_result.loc[merged_df_with_race_info_and_race_result.name==i, ['date','name','rank','velocity']].sort_values('date', ascending=False)
    tmp['prev1_rank']= tmp.shift(periods=-1, axis=0)['rank']
    tmp['prev2_rank']= tmp.shift(periods=-2, axis=0)['rank']
    tmp['prev3_rank']= tmp.shift(periods=-3, axis=0)['rank']
    
    tmp['prev1_velo']= tmp.shift(periods=-1, axis=0)['velocity']
    tmp['prev2_velo']= tmp.shift(periods=-2, axis=0)['velocity']
    tmp['prev3_velo']= tmp.shift(periods=-3, axis=0)['velocity']
    empty_list.append(tmp)

# %%
instrument_to_merge = pd.concat(empty_list)

# %%
len(instrument_to_merge)
# Out:
# 70544

# %%
re_arranged_instrument_to_merge = instrument_to_merge[['date', 'name', 'rank', 'prev1_rank', 'prev2_rank', 'prev3_rank', 'velocity', 'prev1_velo', 'prev2_velo', 'prev3_velo']]
re_arranged_instrument_to_merge
# Out:
#              date    name rank prev1_rank prev2_rank prev3_rank velocity  \
# 0      2018-11-03    승리나래    1         12          취          2      NaN
# 4419   2018-06-10    승리나래   12          취          2          3   14.068
# 5513   2018-05-06    승리나래    취          2          3         10      NaN
# 6497   2018-04-08    승리나래    2          3         10          1  15.7576
# 7447   2018-03-11    승리나래    3         10          1        NaN  15.7959
# 8485   2018-02-04    승리나래   10          1        NaN        NaN  15.5521
# 9971   2017-12-23    승리나래    1        NaN        NaN        NaN  15.8479
# 1      2018-11-03   라스트잭팟    2          6          7         10      NaN
# 1655   2018-09-09   라스트잭팟    6          7         10          5  14.9385
# 3372   2018-07-15   라스트잭팟    7         10          5         11  14.6425
# 4824   2018-05-27   라스트잭팟   10          5         11          9  15.4762
# 6353   2018-04-14   라스트잭팟    5         11          9          7  15.0977
# 9373   2018-01-13   라스트잭팟   11          9          7          3  14.3824
# 10230  2017-12-16   라스트잭팟    9          7          3          2  14.5923
# 11238  2017-11-18   라스트잭팟    7          3          2          1  14.7698
# 11880  2017-10-29   라스트잭팟    3          2          1          4  14.9912
# 12663  2017-10-01   라스트잭팟    2          1          4          5  15.1921
# 13410  2017-09-10   라스트잭팟    1          4          5          7  14.8862
# 13989  2017-08-26   라스트잭팟    4          5          7          5  14.8862
# 14382  2017-08-13   라스트잭팟    5          7          5          6  15.5689
# 15239  2017-07-15   라스트잭팟    7          5          6          6  15.4394
# 15670  2017-07-01   라스트잭팟    5          6          6          9  15.5131
# 16142  2017-06-17   라스트잭팟    6          6          9          7  15.4394
# 16579  2017-06-03   라스트잭팟    6          9          7          7  15.4946
# 17482  2017-05-06   라스트잭팟    9          7          7         12  15.3374
# 18673  2017-04-01   라스트잭팟    7          7         12          8   15.456
# 19678  2017-03-04   라스트잭팟    7         12          8        NaN  15.2905
# 20471  2017-02-11   라스트잭팟   12          8        NaN        NaN  15.3846
# 24121  2016-10-22   라스트잭팟    8        NaN        NaN        NaN  15.5039
# 2      2018-11-03   승리플러스    3          2          6          7      NaN
# ...           ...     ...  ...        ...        ...        ...      ...
# 70069  2013-02-17    라온제나    8        NaN        NaN        NaN  15.4867
# 70072  2013-02-17    골든삭스   11        NaN        NaN        NaN  15.2009
# 70073  2013-02-17   위너트로피   12        NaN        NaN        NaN  15.1844
# 70074  2013-02-17  사일런트대싱   13        NaN        NaN        NaN  15.0862
# 70086  2013-02-17     우람이   11        NaN        NaN        NaN  14.4811
# 70088  2013-02-17    대싱치프    실        NaN        NaN        NaN  13.5747
# 70113  2013-02-17  오디세이아침   12        NaN        NaN        NaN  14.9068
# 70129  2013-02-17   돌풍회오리   14        NaN        NaN        NaN  14.4444
# 70155  2013-02-17   퍼즐커맨더   13        NaN        NaN        NaN  14.7239
# 70188  2013-02-16   문학의여왕    6        NaN        NaN        NaN  15.3677
# 70222  2013-02-16   미스틱우먼   12        NaN        NaN        NaN  14.2518
# 70239  2013-02-16    닥터케이    2        NaN        NaN        NaN  15.3005
# 70292  2013-02-16   라이파댄서   13        NaN        NaN        NaN   14.944
# 70293  2013-02-16   온리빅토리   14        NaN        NaN        NaN  14.7059
# 70301  2013-02-16      근리    8        NaN        NaN        NaN   15.361
# 70313  2013-02-16   문학의비전    7        NaN        NaN        NaN  15.5521
# 70345  2013-02-16     늘사랑   14        NaN        NaN        NaN  14.7059
# 70358  2013-02-03    무패승리   13        NaN        NaN        NaN  15.6047
# 70381  2013-02-03    천년돌풍    취        NaN        NaN        NaN      NaN
# 70410  2013-02-03    서미트윈    1        NaN        NaN        NaN  14.7955
# 70421  2013-02-03    수너베터    중        NaN        NaN        NaN      NaN
# 70435  2013-02-03    칩인버디   14        NaN        NaN        NaN  14.3312
# 70475  2013-02-03    상원챔프   12        NaN        NaN        NaN  14.7275
# 70483  2013-02-03    다이나모    8        NaN        NaN        NaN   15.544
# 70489  2013-02-03    천추공주    제        NaN        NaN        NaN      NaN
# 70501  2013-02-02   브렌트강자   12        NaN        NaN        NaN  15.3509
# 70515  2013-02-02      본솔   12        NaN        NaN        NaN  14.9961
# 70529  2013-02-02    굿메시지    취        NaN        NaN        NaN      NaN
# 70542  2013-02-02  사라토가밴드   13        NaN        NaN        NaN  15.2838
# 70543  2013-02-02     수봉산    실        NaN        NaN        NaN  14.0987
#
#       prev1_velo prev2_velo prev3_velo
# 0         14.068        NaN    15.7576
# 4419         NaN    15.7576    15.7959
# 5513     15.7576    15.7959    15.5521
# 6497     15.7959    15.5521    15.8479
# 7447     15.5521    15.8479        NaN
# 8485     15.8479        NaN        NaN
# 9971         NaN        NaN        NaN
# 1        14.9385    14.6425    15.4762
# 1655     14.6425    15.4762    15.0977
# 3372     15.4762    15.0977    14.3824
# 4824     15.0977    14.3824    14.5923
# 6353     14.3824    14.5923    14.7698
# 9373     14.5923    14.7698    14.9912
# 10230    14.7698    14.9912    15.1921
# 11238    14.9912    15.1921    14.8862
# 11880    15.1921    14.8862    14.8862
# 12663    14.8862    14.8862    15.5689
# 13410    14.8862    15.5689    15.4394
# 13989    15.5689    15.4394    15.5131
# 14382    15.4394    15.5131    15.4394
# 15239    15.5131    15.4394    15.4946
# 15670    15.4394    15.4946    15.3374
# 16142    15.4946    15.3374     15.456
# 16579    15.3374     15.456    15.2905
# 17482     15.456    15.2905    15.3846
# 18673    15.2905    15.3846    15.5039
# 19678    15.3846    15.5039        NaN
# 20471    15.5039        NaN        NaN
# 24121        NaN        NaN        NaN
# 2         15.625    15.3846    15.3664
# ...          ...        ...        ...
# 70069        NaN        NaN        NaN
# 70072        NaN        NaN        NaN
# 70073        NaN        NaN        NaN
# 70074        NaN        NaN        NaN
# 70086        NaN        NaN        NaN
# 70088        NaN        NaN        NaN
# 70113        NaN        NaN        NaN
# 70129        NaN        NaN        NaN
# 70155        NaN        NaN        NaN
# 70188        NaN        NaN        NaN
# 70222        NaN        NaN        NaN
# 70239        NaN        NaN        NaN
# 70292        NaN        NaN        NaN
# 70293        NaN        NaN        NaN
# 70301        NaN        NaN        NaN
# 70313        NaN        NaN        NaN
# 70345        NaN        NaN        NaN
# 70358        NaN        NaN        NaN
# 70381        NaN        NaN        NaN
# 70410        NaN        NaN        NaN
# 70421        NaN        NaN        NaN
# 70435        NaN        NaN        NaN
# 70475        NaN        NaN        NaN
# 70483        NaN        NaN        NaN
# 70489        NaN        NaN        NaN
# 70501        NaN        NaN        NaN
# 70515        NaN        NaN        NaN
# 70529        NaN        NaN        NaN
# 70542        NaN        NaN        NaN
# 70543        NaN        NaN        NaN
#
# [70544 rows x 10 columns]

# %%
final_df = merged_df_with_race_info_and_race_result.merge(re_arranged_instrument_to_merge, how='left', on=['date', 'name','rank','velocity'])

# %%
len(final_df)
# Out:
# 70544

# %%
final_df.to_pickle('/Users/daham/Desktop/GrowthHackers/horserace/neural-network/combined_df_with_prev_ranks_and_prev_velos.pickle')

# %%
final_df[['distance', 'velocity', 'prev1_rank', 'prev2_rank', 'prev3_rank', 'prev1_velo', 'prev2_velo', 'prev3_velo']].to_pickle('/Users/daham/Desktop/GrowthHackers/horserace/neural-network/columns_df_with_prev_ranks_and_prev_velos.pickle')
